# %% [markdown]
# # Question 1

# %% [markdown]
# A water pump has a 10.75-in-diameter impeller and operates at 2,150 rpm. The pump is tested and the flow rate, pump pressure rise, and pump power are measured at the following conditions.

# %% [markdown]
# Measured water pump parameters
#
# | V˙ (gpm)  | ΔP (psi)  | W˙ (hp)|
# | --------  |:--------- | ------ |
# | 41.87     | 86.57 	| 7.123  |
# | 83.74     | 86.35 	| 10.23  |
# | 125.6     | 82.05 	| 12.04  |
# | 167.5     | 77.95 	| 13.30  |
# | 209.4     | 72.14 	| 14.38  |
# | 251.2     | 64.82 	| 15.73  |
# | 293.1     | 55.56 	| 18.03  |
#
#
#
# For the given test data, find the flow coefficient at a pump flow rate of 167.5 gpm.
#
# Report all answer to 3 significant digits.

# %%
import matplotlib.pyplot as plt
vdot = [41.87,83.74,125.6,167.5,209.4,251.2,293.1]
P = [86.57,86.35, 82.05, 77.95, 72.14, 64.82, 55.56]
Wdot = [7.123,10.23,12.04,13.30,14.38,15.73,18.03]

# %% [markdown]
# # Question 2

# %% [markdown]
# A water pump has a 11-in-diameter impeller and operates at 2,100 rpm. The pump is tested and the flow rate, pump pressure rise, and pump power are measured at the following conditions.

# %% [markdown]
#  Measured water pump parameters
#
# |V˙ (gpm) |ΔP (psi) |W˙ (hp)|
# | --------|:--------| ------|
# |43.82 	  |86.47 	|7.447  |
# |87.64 	  |86.26 	|10.70  |
# |131.5 	  |81.96 	|12.58  |
# |175.3 	  |77.87 	|13.90  |
# |219.1 	  |72.06 	|15.03  |
# |262.9 	  |64.75 	|16.45  |
# |306.7 	  |55.50 	|18.85  |
#
#
#
# For the given test data, find the head coefficient at a pump flow rate of 131.5 gpm.
#
# Report all answer to 3 significant digits.

# %%
vdot = [43.82,87.64,131.5,175.3,219.1,262.9,306.7]
P = [86.47,86.26,81.96,77.87,72.06,64.75,55.50]
Wdot = [7.447,10.70,12.58,13.90,15.03,16.45,18.85]

# %% [markdown]
# # Question 3

# %% [markdown]
# A water pump has a 6-in-diameter impeller and operates at 2,300 rpm. The pump is tested and the flow rate, pump pressure rise, and pump power are measured at the following conditions.

# %% [markdown]
#  Measured water pump parameters
#
# |V˙ (gpm) |ΔP (psi) |W˙ (hp)|
# | --------|:--------| ------|
# |7.788 	  |30.86 	|0.4724 |
# |15.58 	  |30.79 	|0.6786 |
# |23.37 	  |29.25 	|0.7982 |
# |31.15 	  |27.79 	|0.8819 |
# |38.94 	  |25.72 	|0.9537 |
# |46.73 	  |23.11 	|1.043  |
# |54.52 	  |19.81 	|1.196  |
#
#
#
# For the given test data, find the power coefficient at a pump flow rate of 23.37 gpm.
#
# Report all answer to 3 significant digits.

# %%
vdot = [7.788,15.58,23.37,31.15,38.94,46.73,54.52]
P = [30.86,30.79,29.25,27.79,25.72,23.11,19.81]
Wdot = [0.4724,0.6786,0.7982,0.8819,0.9537,1.043,1.196]

# %% [markdown]
# # Question 4

# %% [markdown]
# A water pump has a 10-in-diameter impeller and operates at 2,200 rpm. The pump is tested and the flow rate, pump pressure rise, and pump power are measured at the following conditions.

# %% [markdown]
#  Measured water pump parameters
#
# |V˙ (gpm) |ΔP (psi) |W˙ (hp)|
# | --------|:--------| ------|
# |34.49 	  |78.44 	|5.316  |
# |68.98 	  |78.24 	|7.638  |
# |103.5 	  |74.34 	|8.984  |
# |138.0 	  |70.63 	|9.926  |
# |172.4 	  |65.36 	|10.73  |
# |206.9 	  |58.73 	|11.74  |
# |241.4 	  |50.34 	|13.46  |
#
#
#
# For the given test data, find the pump efficiency at the best efficiency point (BEP). Report at a decimal number, not a percentage.
#
#
#
# Report all answer to 3 significant digits.

# %%
vdot = [34.49,68.98,103.5,138.0,172.4,206.9,241.4]
P = [78.44,78.24,74.34,70.63,65.36,58.73,50.34]
Wdot = [5.316,7.638,8.984,9.926,10.73,11.74,13.46]

# %% [markdown]
# # Question 5

# %% [markdown]
# Using the test data in the previous section (where you found the efficiency at BEP), for a similar pump with a diameter 2.5 inches and a speed of 3,125 rpm, what is the flow rate and pressure rise at the best efficiency point?
#
# Report all answer to 3 significant digits.

# %%
from IPython.display import Image
Image(filename="PumpPlot.png")
