# %%
print('Hello World')
# Out:
# Hello World

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 10, 0.1)
plt.plot(x, np.cos(x))
plt.show()

# %% [markdown]
# $$e^{i \pi } + 1 = 0$$
