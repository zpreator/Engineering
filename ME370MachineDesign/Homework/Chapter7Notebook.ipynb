# %%
# %%html
# <embed src-“HW21.pdf” width=”600” height=”500”> </embed>
# Out:
# <embed src-“HW21.pdf” width=”600” height=”500”> </embed>

# %%
from IPython.display import Image
Image(filename="Figures/TableA20Header.png")

# %%
Image(filename="Figures/aisi1095.png")
